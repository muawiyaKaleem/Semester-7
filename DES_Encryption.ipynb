# %%
import binascii
import base64

# %% [markdown]
# # **Permutation Tables**

# %%
"""initial permutation table"""
ip_table = [
        58, 50, 42, 34, 26, 18, 10, 2,
        60, 52, 44, 36, 28, 20, 12, 4,
        62, 54, 46, 38, 30, 22, 14, 6,
        64, 56, 48, 40, 32, 24, 16, 8,
        57, 49, 41, 33, 25, 17, 9,  1,
        59, 51, 43, 35, 27, 19, 11, 3,
        61, 53, 45, 37, 29, 21, 13, 5,
        63, 55, 47, 39, 31, 23, 15, 7
    ]

"""Expension permutation table"""
E_table = [
      32, 1, 2, 3, 4, 5,
        4, 5, 6, 7, 8, 9,
    8, 9, 10, 11, 12, 13,
  12, 13, 14, 15, 16, 17,
  16, 17, 18, 19, 20, 21,
  20, 21, 22, 23, 24, 25,
  24, 25, 26, 27, 28, 29,
  28, 29, 30, 31, 32, 1
            ]

"""Substitution table 1"""
S1 = [
    [14, 4, 13, 1, 2, 15, 11, 8, 3, 10, 6, 12, 5, 9, 0, 7],
    [0, 15, 7, 4, 14, 2, 13, 1, 10, 6, 12, 11, 9, 5, 3, 8],
    [4, 1, 14, 8, 13, 6, 2, 11, 15, 12, 9, 7, 3, 10, 5, 0],
    [15, 12, 8, 2, 4, 9, 1, 7, 5, 11, 3, 14, 10, 0, 6, 13]
]

"""Substitution table 2"""
S2 = [
    [15, 1, 8, 14, 6, 11, 3, 4, 9, 7, 2, 13, 12, 0, 5, 10],
    [3, 13, 4, 7, 15, 2, 8, 14, 12, 0, 1, 10, 6, 9, 11, 5],
    [0, 14, 7, 11, 10, 4, 13, 1, 5, 8, 12, 6, 9, 3, 2, 15],
    [13, 8, 10, 1, 3, 15, 4, 2, 11, 6, 7, 12, 0, 5, 14, 9]
]

"""Substitution table 3"""
S3 = [
    [10, 0, 9, 14, 6, 3, 15, 5, 1, 13, 12, 7, 11, 4, 2, 8],
    [13, 7, 0, 9, 3, 4, 6, 10, 2, 8, 5, 14, 12, 11, 15, 1],
    [13, 6, 4, 9, 8, 15, 3, 0, 11, 1, 2, 12, 5, 10, 14, 7],
    [1, 10, 13, 0, 6, 9, 8, 7, 4, 15, 14, 3, 11, 5, 2, 12]
]

"""Substitution table 4"""
S4 = [
    [7, 13, 14, 3, 0, 6, 9, 10, 1, 2, 8, 5, 11, 12, 4, 15],
    [13, 8, 11, 5, 6, 15, 0, 3, 4, 7, 2, 12, 1, 10, 14, 9],
    [10, 6, 9, 0, 12, 11, 7, 13, 15, 1, 3, 14, 5, 2, 8, 4],
    [3, 15, 0, 6, 10, 1, 13, 8, 9, 4, 5, 11, 12, 7, 2, 14]
]

"""Substitution table 5"""
S5 = [
    [2, 12, 4, 1, 7, 10, 11, 6, 8, 5, 3, 15, 13, 0, 14, 9],
    [14, 11, 2, 12, 4, 7, 13, 1, 5, 0, 15, 10, 3, 9, 8, 6],
    [4, 2, 1, 11, 10, 13, 7, 8, 15, 9, 12, 5, 6, 3, 0, 14],
    [11, 8, 12, 7, 1, 14, 2, 13, 6, 15, 0, 9, 10, 4, 5, 3]
]

"""Substitution table 6"""
S6 = [
    [12, 1, 10, 15, 9, 2, 6, 8, 0, 13, 3, 4, 14, 7, 5, 11],
    [10, 15, 4, 2, 7, 12, 9, 5, 6, 1, 13, 14, 0, 11, 3, 8],
    [9, 14, 15, 5, 2, 8, 12, 3, 7, 0, 4, 10, 1, 13, 11, 6],
    [4, 3, 2, 12, 9, 5, 15, 10, 11, 14, 1, 7, 6, 0, 8, 13]
]

"""Substitution table 7"""
S7 = [
    [4, 11, 2, 14, 15, 0, 8, 13, 3, 12, 9, 7, 5, 10, 6, 1],
    [13, 0, 11, 7, 4, 9, 1, 10, 14, 3, 5, 12, 2, 15, 8, 6],
    [1, 4, 11, 13, 12, 3, 7, 14, 10, 15, 6, 8, 0, 5, 9, 2],
    [6, 11, 13, 8, 1, 4, 10, 7, 9, 5, 0, 15, 14, 2, 3, 12]
]

"""Substitution table 8"""
S8 = [
    [13, 2, 8, 4, 6, 15, 11, 1, 10, 9, 3, 14, 5, 0, 12, 7],
    [1, 15, 13, 8, 10, 3, 7, 4, 12, 5, 6, 11, 0, 14, 9, 2],
    [7, 11, 4, 1, 9, 12, 14, 2, 0, 6, 10, 13, 15, 3, 5, 8],
    [2, 1, 14, 7, 4, 10, 8, 13, 15, 12, 9, 0, 3, 5, 6, 11]
]

"""permutation table after Substitution"""
p_32 = [16, 7, 20, 21,
        29, 12, 28, 17,
        1, 15, 23, 26,
        5, 18, 31, 10,
        2, 8, 24, 14,
        32, 27, 3, 9,
        19, 13, 30, 6,
        22, 11, 4, 25]

"""Final permutation table"""

final = [40, 8, 48, 16, 56, 24, 64, 32,
         39, 7, 47, 15, 55, 23, 63, 31,
         38, 6, 46, 14, 54, 22, 62, 30,
         37, 5, 45, 13, 53, 21, 61, 29,
         36, 4, 44, 12, 52, 20, 60, 28,
         35, 3, 43, 11, 51, 19, 59, 27,
         34, 2, 42, 10, 50, 18, 58, 26,
         33, 1, 41, 9, 49, 17, 57, 25]

"""first permutation table for the key"""
PC_1 = [57, 49, 41, 33, 25, 17, 9,
        1, 58, 50, 42, 34, 26, 18,
        10, 2, 59, 51, 43, 35, 27,
        19, 11, 3, 60, 52, 44, 36,
        63, 55, 47, 39, 31, 23, 15,
        7, 62, 54, 46, 38, 30, 22,
        14, 6, 61, 53, 45, 37, 29,
        21, 13, 5, 28, 20, 12, 4]

"""second permutation table for the key"""
PC_2 = [14, 17, 11, 24, 1, 5,
        3, 28, 15, 6, 21, 10,
        23, 19, 12, 4, 26, 8,
        16, 7, 27, 20, 13, 2,
        41, 52, 31, 37, 47, 55,
        30, 40, 51, 45, 33, 48,
        44, 49, 39, 56, 34, 53,
        46, 42, 50, 36, 29, 32]

S_box = [S1,S2,S3,S4,S5,S6,S7,S8]

# %% [markdown]
# # ***Functions of the DES***

# %%
"""Making chunks of 64 bits of user based input"""
def input_to_64bit_chunks(input_value):
# Convert each character to its 8-bit binary ASCII value
    if input_value == text:
      binary_str = ''.join(format(ord(char), '08b') for char in text)

# Split the binary string into 64-bit chunks
      chunks = [binary_str[i:i+64] for i in range(0, len(binary_str), 64)]

# Pad the last chunk to ensure it's exactly 64 bits
      if len(chunks[-1]) < 64:
        chunks[-1] = chunks[-1].ljust(64, '0')

      return chunks

    elif input_value == key:
      binary_str = ''.join(format(ord(char), '08b') for char in key)
      # Ensure it's 64 bits long
      binary_str = binary_str.ljust(64, '0')

      return binary_str

"""Initial permutation of the input chunks"""
def initial_permutation(x):
    y=0
    while y != len(chunks) - 1:

      chunk_element = chunks[y]
      chunks[y] = permutation(chunk_element,ip_table) # permutation function call

      y += 1

    return chunks

""""Permutation process"""
def permutation(bits,table):
    p_bits = ''.join(bits[i-1] for i in table)
    return p_bits

""""Apply the first permutation on the key"""
def pc_1(key):
    key = ''.join(key[i-1] for i in PC_1)
    return key

"""break the 56 bit key into 2 parts"""
def key_break(key):
    C = key[:28]
    D = key[28:]
    return C,D

"""Left Shifting of bits"""
def left_shifting(x,shift_amount):
  C = x[0]
  D = x[1]

  if shift_amount == 1:
    C = C[1:] + C[0]
    D = D[1:] + D[0]
  elif shift_amount == 2:
    C = C[2:] + C[:2]
    D = D[2:] + D[:2]

  return C,D

"""generating the 16 keys using the shifting table"""
def key_generation():

  keys = []
  keys.append(pc_1(key))
  shifts = [1,1,2,2,2,2,2,2,1,2,2,2,2,2,2,1]

         # generating 16 keys loop
  for i in range (0,16):

      C,D = left_shifting(key_break(keys[i]),shifts[i])
      keys.append(C+D)
# removing the first copied key
  keys.remove(keys[0])
  return keys

"""second permutation of the each key to 48 bits"""
def pc_2(keys):

  for i in range(0,16):
    keys[i] = ''.join(keys[i][j-1] for j in PC_2)
  return keys

"""X-OR the 48 bits key with the expended text bits"""
def XOR(bits1, bits2):
    xor = ''.join(str(int(b1) ^ int(b2)) for b1,b2 in zip(bits1,bits2))
    return xor

"""Substitution box process"""
def S_box_substitution(array,S_box):

  for i in range(len(array)):
                first = array[i][0]
                last = array[i][-1]
                column =  int(array[i][1:-1], 2)
                rows =  int(first + last, 2)
                array[i] = str(bin(S_box[i][rows][column])[2:]).zfill(4)
  array = ''.join(array)
  return array

"""feistal function of the DES network"""
def feistal(bit,subkey):
  f_xor = XOR(bit , subkey)
  slicing = [f_xor[i:i+6] for i in range(0, len(f_xor), 6)]
  substituted_4bit = S_box_substitution(slicing,S_box)
  newbit = ''.join(substituted_4bit[i-1] for i in p_32)
  return newbit

"""Expansion of input and key mixing """
def Expansion_Permutation(x,keys):

            # Apply the initial permutation

      y = 0
      while y != len(x) - 1:
              R = chunks[y][:32]
              L = chunks[y][32:]

              for i in range(0,16):
 # permute each part of the chunk to make it 48 bit
                R = permutation(R,E_table)
  # feistal fucntion of the DES network
                f_bit = feistal(R,keys[i])

                n_xor = XOR(f_bit, L)

                L = R
                R = n_xor

              chunks[y] = R + L
# final permutation
              chunks[y] = permutation(chunks[y],final)
              y += 1

      return chunks

"""Convert cipher bits to cipher text"""
def cipher(cipher_bits):
    cipher_text = ""
    for i in range(0, len(cipher_bits),8):
        # Extract 8-bit chunks from cipher_text
        chunk_8bit = cipher_bits[i:i + 8]
        # Convert binary chunk to ASCII character
        ascii_value = int(chunk_8bit, 2)
        cipher_text += chr(ascii_value)
    return cipher_text

# %% [markdown]
# # **Input and output**

# %%
# Input text and key
text = input()
key = "KeyDES64"
chunks = input_to_64bit_chunks(text)
key = input_to_64bit_chunks(key)

# Output cipher text
chunks = Expansion_Permutation(chunks,key_generation())
cipher_bits = ''.join(chunks)
cipher_text = cipher(cipher_bits)

# handle the unprintbale characters or characters out of range of ascii
cipher_text = base64.b64encode(cipher_text.encode()).decode()
print(cipher_text)
# Out:
# fuck you
# ZnVjayB5b3U=

# %%
"""
"KeyDES64"
"SafeLock"
"Crypto42"
"SecureIt"
"Cipher77"
"""
# Out:
#   File "<ipython-input-32-4f4c2d050e89>", line 1
#     h"""
#      ^
# SyntaxError: invalid syntax
